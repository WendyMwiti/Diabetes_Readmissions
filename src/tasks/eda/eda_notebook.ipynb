# %% [markdown]
# ## Data Description
# > In this phase, we describe the meanings of each column
#
# The data descriptions can be found here: ("https://archive.ics.uci.edu/dataset/296/diabetes+130-us+hospitals+for+years+1999-2008")

# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import stats

# %%
# load data
df = pd.read_csv('/home/teofilo_acholla_ligawa_gafna/Documents/python_practice/collaborations/Diabetes_Readmissions/data/diabetic_data.csv')

# preview
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
# preview tail for consistency
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Preliminary Data Inspection
# > In the phase, the study shall seek to undersatand the 'data' about the data.

# %%
# metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
#  13  num_procedures            101766 non-null  int64
#  14  num_medications           101766 non-null  int64
#  15  number_outpatient         101766 non-null  int64
#  16  number_emergency          101766 non-null  int64
#  17  number_inpatient          101766 non-null  int64
#  18  diag_1                    101766 non-null  object
#  19  diag_2                    101766 non-null  object
#  20  diag_3                    101766 non-null  object
#  21  number_diagnoses          101766 non-null  int64
#  22  max_glu_serum             101766 non-null  object
#  23  A1Cresult                 101766 non-null  object
#  24  metformin                 101766 non-null  object
#  25  repaglinide               101766 non-null  object
#  26  nateglinide               101766 non-null  object
#  27  chlorpropamide            101766 non-null  object
#  28  glimepiride               101766 non-null  object
#  29  acetohexamide             101766 non-null  object
#  30  glipizide                 101766 non-null  object
#  31  glyburide                 101766 non-null  object
#  32  tolbutamide               101766 non-null  object
#  33  pioglitazone              101766 non-null  object
#  34  rosiglitazone             101766 non-null  object
#  35  acarbose                  101766 non-null  object
#  36  miglitol                  101766 non-null  object
#  37  troglitazone              101766 non-null  object
#  38  tolazamide                101766 non-null  object
#  39  examide                   101766 non-null  object
#  40  citoglipton               101766 non-null  object
#  41  insulin                   101766 non-null  object
#  42  glyburide-metformin       101766 non-null  object
#  43  glipizide-metformin       101766 non-null  object
#  44  glimepiride-pioglitazone  101766 non-null  object
#  45  metformin-rosiglitazone   101766 non-null  object
#  46  metformin-pioglitazone    101766 non-null  object
#  47  change                    101766 non-null  object
#  48  diabetesMed               101766 non-null  object
#  49  readmitted                101766 non-null  object
# dtypes: int64(13), object(37)
# memory usage: 38.8+ MB

# %%
def inspect_df(df):
    """This prints out the summary from the inspection of the data"""

    return {"Dimensions": f"This data set has {df.shape[0]} rows and {df.shape[1]} columns",
            "Duplicates": f"The data has {df.duplicated().sum()} duplicated entries and {len(df) - df.duplicated().sum()} non duplicated entries",
            "Missing values (%)": f"{(df.isna().sum().sum() / (df.shape[0] * df.shape[1])) * 100} % of the data has missing values",
            "Summary statistics": df.describe().T,
            "Info (printed above)":df.info()}

def inspect_col(df, col):
  """Summary Inspection of the column in focus"""
  
  return {"Top 5 value counts": df[col].value_counts()[:5],
          "Number of unique values": df[col].nunique(),
          "data type": df[col].dtype,
          "Missing Values": f"{col} has {df[col].isna().sum()} missing values. This equates to {round(df[col].isna().sum()/df.__len__(),5) * 100} % missing"}
  
  
  # Summary data of the data frame
inspect_df(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      99493 non-null   object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    3197 non-null    object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                61510 non-null   object
#  11  medical_specialty         51817 non-null   object
#  12  num_lab_procedures        101766 non-null  int64
#  13  num_procedures            101766 non-null  int64
#  14  num_medications           101766 non-null  int64
#  15  number_outpatient         101766 non-null  int64
#  16  number_emergency          101766 non-null  int64
#  17  number_inpatient          101766 non-null  int64
#  18  diag_1                    101745 non-null  object
#  19  diag_2                    101408 non-null  object
#  20  diag_3                    100343 non-null  object
#  21  number_diagnoses          101766 non-null  int64
#  22  max_glu_serum             101766 non-null  object
#  23  A1Cresult                 101766 non-null  object
#  24  metformin                 101766 non-null  object
#  25  repaglinide               101766 non-null  object
#  26  nateglinide               101766 non-null  object
#  27  chlorpropamide            101766 non-null  object
#  28  glimepiride               101766 non-null  object
#  29  acetohexamide             101766 non-null  object
#  30  glipizide                 101766 non-null  object
#  31  glyburide                 101766 non-null  object
#  32  tolbutamide               101766 non-null  object
#  33  pioglitazone              101766 non-null  object
#  34  rosiglitazone             101766 non-null  object
#  35  acarbose                  101766 non-null  object
#  36  miglitol                  101766 non-null  object
#  37  troglitazone              101766 non-null  object
#  38  tolazamide                101766 non-null  object
#  39  examide                   101766 non-null  object
#  40  citoglipton               101766 non-null  object
#  41  insulin                   101766 non-null  object
#  42  glyburide-metformin       101766 non-null  object
#  43  glipizide-metformin       101766 non-null  object
#  44  glimepiride-pioglitazone  101766 non-null  object
#  45  metformin-rosiglitazone   101766 non-null  object
#  46  metformin-pioglitazone    101766 non-null  object
#  47  change                    101766 non-null  object
#  48  diabetesMed               101766 non-null  object
#  49  readmitted                101766 non-null  object
# dtypes: int64(13), object(37)
# memory usage: 38.8+ MB
# {'Dimensions': 'This data set has 101766 rows and 50 columns',
#  'Duplicates': 'The data has 0 duplicated entries and 101766 non duplicated entries',
#  'Missing values (%)': '3.790047756618124 % of the data has missing values',
#  'Summary statistics':                              count          mean           std      min  \
#  encounter_id              101766.0  1.652016e+08  1.026403e+08  12522.0
#  patient_nbr               101766.0  5.433040e+07  3.869636e+07    135.0
#  admission_type_id         101766.0  2.024006e+00  1.445403e+00      1.0
#  discharge_disposition_id  101766.0  3.715642e+00  5.280166e+00      1.0
#  admission_source_id       101766.0  5.754437e+00  4.064081e+00      1.0
#  time_in_hospital          101766.0  4.395987e+00  2.985108e+00      1.0
#  num_lab_procedures        101766.0  4.309564e+01  1.967436e+01      1.0
#  num_procedures            101766.0  1.339730e+00  1.705807e+00      0.0
#  num_medications           101766.0  1.602184e+01  8.127566e+00      1.0
#  number_outpatient         101766.0  3.693572e-01  1.267265e+00      0.0
#  number_emergency          101766.0  1.978362e-01  9.304723e-01      0.0
#  number_inpatient          101766.0  6.355659e-01  1.262863e+00      0.0
#  number_diagnoses          101766.0  7.422607e+00  1.933600e+00      1.0
#
#                                   25%          50%           75%          max
#  encounter_id              84961194.0  152388987.0  2.302709e+08  443867222.0
#  patient_nbr               23413221.0   45505143.0  8.754595e+07  189502619.0
#  admission_type_id                1.0          1.0  3.000000e+00          8.0
#  discharge_disposition_id         1.0          1.0  4.000000e+00         28.0
#  admission_source_id              1.0          7.0  7.000000e+00         25.0
#  time_in_hospital                 2.0          4.0  6.000000e+00         14.0
#  num_lab_procedures              31.0         44.0  5.700000e+01        132.0
#  num_procedures                   0.0          1.0  2.000000e+00          6.0
#  num_medications                 10.0         15.0  2.000000e+01         81.0
#  number_outpatient                0.0          0.0  0.000000e+00         42.0
#  number_emergency                 0.0          0.0  0.000000e+00         76.0
#  number_inpatient                 0.0          0.0  1.000000e+00         21.0
#  number_diagnoses                 6.0          8.0  9.000000e+00         16.0  ,
#  'Info (printed above)': None}

# %%
# making summary statistics clear
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    4.000000             7.000000          6.000000
# max                   28.000000            25.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count       101766.000000   101766.000000    101766.000000      101766.000000
# mean            43.095641        1.339730        16.021844           0.369357
# std             19.674362        1.705807         8.127566           1.267265
# min              1.000000        0.000000         1.000000           0.000000
# 25%             31.000000        0.000000        10.000000           0.000000
# 50%             44.000000        1.000000        15.000000           0.000000
# 75%             57.000000        2.000000        20.000000           0.000000
# max            132.000000        6.000000        81.000000          42.000000
#
#        number_emergency  number_inpatient  number_diagnoses
# count     101766.000000     101766.000000     101766.000000
# mean           0.197836          0.635566          7.422607
# std            0.930472          1.262863          1.933600
# min            0.000000          0.000000          1.000000
# 25%            0.000000          0.000000          6.000000
# 50%            0.000000          0.000000          8.000000
# 75%            0.000000          1.000000          9.000000
# max           76.000000         21.000000         16.000000

# %% [markdown]
# The findings from above indicate that there is no missing value yet upon inspection of the first five rows, there were question marks which do not provide us with any meaningful information thus the study considers them as missing values and to regard them as such, they shall be replaced by NaN.

# %%
# replacing with NAN
df.replace('?', np.nan, inplace=True)

# Preview
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
# Inspect the data once more
inspect_df(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      99493 non-null   object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    3197 non-null    object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                61510 non-null   object
#  11  medical_specialty         51817 non-null   object
#  12  num_lab_procedures        101766 non-null  int64
#  13  num_procedures            101766 non-null  int64
#  14  num_medications           101766 non-null  int64
#  15  number_outpatient         101766 non-null  int64
#  16  number_emergency          101766 non-null  int64
#  17  number_inpatient          101766 non-null  int64
#  18  diag_1                    101745 non-null  object
#  19  diag_2                    101408 non-null  object
#  20  diag_3                    100343 non-null  object
#  21  number_diagnoses          101766 non-null  int64
#  22  max_glu_serum             101766 non-null  object
#  23  A1Cresult                 101766 non-null  object
#  24  metformin                 101766 non-null  object
#  25  repaglinide               101766 non-null  object
#  26  nateglinide               101766 non-null  object
#  27  chlorpropamide            101766 non-null  object
#  28  glimepiride               101766 non-null  object
#  29  acetohexamide             101766 non-null  object
#  30  glipizide                 101766 non-null  object
#  31  glyburide                 101766 non-null  object
#  32  tolbutamide               101766 non-null  object
#  33  pioglitazone              101766 non-null  object
#  34  rosiglitazone             101766 non-null  object
#  35  acarbose                  101766 non-null  object
#  36  miglitol                  101766 non-null  object
#  37  troglitazone              101766 non-null  object
#  38  tolazamide                101766 non-null  object
#  39  examide                   101766 non-null  object
#  40  citoglipton               101766 non-null  object
#  41  insulin                   101766 non-null  object
#  42  glyburide-metformin       101766 non-null  object
#  43  glipizide-metformin       101766 non-null  object
#  44  glimepiride-pioglitazone  101766 non-null  object
#  45  metformin-rosiglitazone   101766 non-null  object
#  46  metformin-pioglitazone    101766 non-null  object
#  47  change                    101766 non-null  object
#  48  diabetesMed               101766 non-null  object
#  49  readmitted                101766 non-null  object
# dtypes: int64(13), object(37)
# memory usage: 38.8+ MB
# {'Dimensions': 'This data set has 101766 rows and 50 columns',
#  'Duplicates': 'The data has 0 duplicated entries and 101766 non duplicated entries',
#  'Missing values (%)': '3.790047756618124 % of the data has missing values',
#  'Summary statistics':                              count          mean           std      min  \
#  encounter_id              101766.0  1.652016e+08  1.026403e+08  12522.0
#  patient_nbr               101766.0  5.433040e+07  3.869636e+07    135.0
#  admission_type_id         101766.0  2.024006e+00  1.445403e+00      1.0
#  discharge_disposition_id  101766.0  3.715642e+00  5.280166e+00      1.0
#  admission_source_id       101766.0  5.754437e+00  4.064081e+00      1.0
#  time_in_hospital          101766.0  4.395987e+00  2.985108e+00      1.0
#  num_lab_procedures        101766.0  4.309564e+01  1.967436e+01      1.0
#  num_procedures            101766.0  1.339730e+00  1.705807e+00      0.0
#  num_medications           101766.0  1.602184e+01  8.127566e+00      1.0
#  number_outpatient         101766.0  3.693572e-01  1.267265e+00      0.0
#  number_emergency          101766.0  1.978362e-01  9.304723e-01      0.0
#  number_inpatient          101766.0  6.355659e-01  1.262863e+00      0.0
#  number_diagnoses          101766.0  7.422607e+00  1.933600e+00      1.0
#
#                                   25%          50%           75%          max
#  encounter_id              84961194.0  152388987.0  2.302709e+08  443867222.0
#  patient_nbr               23413221.0   45505143.0  8.754595e+07  189502619.0
#  admission_type_id                1.0          1.0  3.000000e+00          8.0
#  discharge_disposition_id         1.0          1.0  4.000000e+00         28.0
#  admission_source_id              1.0          7.0  7.000000e+00         25.0
#  time_in_hospital                 2.0          4.0  6.000000e+00         14.0
#  num_lab_procedures              31.0         44.0  5.700000e+01        132.0
#  num_procedures                   0.0          1.0  2.000000e+00          6.0
#  num_medications                 10.0         15.0  2.000000e+01         81.0
#  number_outpatient                0.0          0.0  0.000000e+00         42.0
#  number_emergency                 0.0          0.0  0.000000e+00         76.0
#  number_inpatient                 0.0          0.0  1.000000e+00         21.0
#  number_diagnoses                 6.0          8.0  9.000000e+00         16.0  ,
#  'Info (printed above)': None}

# %%
# Inspecting each column
for col in df.columns:
    print(col)
    print(inspect_col(df, col))
    print("="*70)
# Out:
# encounter_id
# {'Top 5 value counts': 2278392      1
# 190792044    1
# 190790070    1
# 190789722    1
# 190786806    1
# Name: encounter_id, dtype: int64, 'Number of unique values': 101766, 'data type': dtype('int64'), 'Missing Values': 'encounter_id has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# patient_nbr
# {'Top 5 value counts': 88785891    40
# 43140906    28
# 1660293     23
# 88227540    23
# 23199021    23
# Name: patient_nbr, dtype: int64, 'Number of unique values': 71518, 'data type': dtype('int64'), 'Missing Values': 'patient_nbr has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# race
# {'Top 5 value counts': Caucasian          76099
# AfricanAmerican    19210
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64, 'Number of unique values': 5, 'data type': dtype('O'), 'Missing Values': 'race has 2273 missing values. This equates to 2.234 % missing'}
# ======================================================================
# gender
# {'Top 5 value counts': Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64, 'Number of unique values': 3, 'data type': dtype('O'), 'Missing Values': 'gender has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# age
# {'Top 5 value counts': [70-80)    26068
# [60-70)    22483
# [50-60)    17256
# [80-90)    17197
# [40-50)     9685
# Name: age, dtype: int64, 'Number of unique values': 10, 'data type': dtype('O'), 'Missing Values': 'age has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# weight
# {'Top 5 value counts': [75-100)     1336
# [50-75)       897
# [100-125)     625
# [125-150)     145
# [25-50)        97
# Name: weight, dtype: int64, 'Number of unique values': 9, 'data type': dtype('O'), 'Missing Values': 'weight has 98569 missing values. This equates to 96.858 % missing'}
# ======================================================================
# admission_type_id
# {'Top 5 value counts': 1    53990
# 3    18869
# 2    18480
# 6     5291
# 5     4785
# Name: admission_type_id, dtype: int64, 'Number of unique values': 8, 'data type': dtype('int64'), 'Missing Values': 'admission_type_id has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# discharge_disposition_id
# {'Top 5 value counts': 1     60234
# 3     13954
# 6     12902
# 18     3691
# 2      2128
# Name: discharge_disposition_id, dtype: int64, 'Number of unique values': 26, 'data type': dtype('int64'), 'Missing Values': 'discharge_disposition_id has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# admission_source_id
# {'Top 5 value counts': 7     57494
# 1     29565
# 17     6781
# 4      3187
# 6      2264
# Name: admission_source_id, dtype: int64, 'Number of unique values': 17, 'data type': dtype('int64'), 'Missing Values': 'admission_source_id has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# time_in_hospital
# {'Top 5 value counts': 3    17756
# 2    17224
# 1    14208
# 4    13924
# 5     9966
# Name: time_in_hospital, dtype: int64, 'Number of unique values': 14, 'data type': dtype('int64'), 'Missing Values': 'time_in_hospital has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# payer_code
# {'Top 5 value counts': MC    32439
# HM     6274
# SP     5007
# BC     4655
# MD     3532
# Name: payer_code, dtype: int64, 'Number of unique values': 17, 'data type': dtype('O'), 'Missing Values': 'payer_code has 40256 missing values. This equates to 39.556999999999995 % missing'}
# ======================================================================
# medical_specialty
# {'Top 5 value counts': InternalMedicine          14635
# Emergency/Trauma           7565
# Family/GeneralPractice     7440
# Cardiology                 5352
# Surgery-General            3099
# Name: medical_specialty, dtype: int64, 'Number of unique values': 72, 'data type': dtype('O'), 'Missing Values': 'medical_specialty has 49949 missing values. This equates to 49.082 % missing'}
# ======================================================================
# num_lab_procedures
# {'Top 5 value counts': 1     3208
# 43    2804
# 44    2496
# 45    2376
# 38    2213
# Name: num_lab_procedures, dtype: int64, 'Number of unique values': 118, 'data type': dtype('int64'), 'Missing Values': 'num_lab_procedures has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# num_procedures
# {'Top 5 value counts': 0    46652
# 1    20742
# 2    12717
# 3     9443
# 6     4954
# Name: num_procedures, dtype: int64, 'Number of unique values': 7, 'data type': dtype('int64'), 'Missing Values': 'num_procedures has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# num_medications
# {'Top 5 value counts': 13    6086
# 12    6004
# 11    5795
# 15    5792
# 14    5707
# Name: num_medications, dtype: int64, 'Number of unique values': 75, 'data type': dtype('int64'), 'Missing Values': 'num_medications has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# number_outpatient
# {'Top 5 value counts': 0    85027
# 1     8547
# 2     3594
# 3     2042
# 4     1099
# Name: number_outpatient, dtype: int64, 'Number of unique values': 39, 'data type': dtype('int64'), 'Missing Values': 'number_outpatient has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# number_emergency
# {'Top 5 value counts': 0    90383
# 1     7677
# 2     2042
# 3      725
# 4      374
# Name: number_emergency, dtype: int64, 'Number of unique values': 33, 'data type': dtype('int64'), 'Missing Values': 'number_emergency has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# number_inpatient
# {'Top 5 value counts': 0    67630
# 1    19521
# 2     7566
# 3     3411
# 4     1622
# Name: number_inpatient, dtype: int64, 'Number of unique values': 21, 'data type': dtype('int64'), 'Missing Values': 'number_inpatient has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# diag_1
# {'Top 5 value counts': 428    6862
# 414    6581
# 786    4016
# 410    3614
# 486    3508
# Name: diag_1, dtype: int64, 'Number of unique values': 716, 'data type': dtype('O'), 'Missing Values': 'diag_1 has 21 missing values. This equates to 0.021 % missing'}
# ======================================================================
# diag_2
# {'Top 5 value counts': 276    6752
# 428    6662
# 250    6071
# 427    5036
# 401    3736
# Name: diag_2, dtype: int64, 'Number of unique values': 748, 'data type': dtype('O'), 'Missing Values': 'diag_2 has 358 missing values. This equates to 0.35200000000000004 % missing'}
# ======================================================================
# diag_3
# {'Top 5 value counts': 250    11555
# 401     8289
# 276     5175
# 428     4577
# 427     3955
# Name: diag_3, dtype: int64, 'Number of unique values': 789, 'data type': dtype('O'), 'Missing Values': 'diag_3 has 1423 missing values. This equates to 1.398 % missing'}
# ======================================================================
# number_diagnoses
# {'Top 5 value counts': 9    49474
# 5    11393
# 8    10616
# 7    10393
# 6    10161
# Name: number_diagnoses, dtype: int64, 'Number of unique values': 16, 'data type': dtype('int64'), 'Missing Values': 'number_diagnoses has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# max_glu_serum
# {'Top 5 value counts': None    96420
# Norm     2597
# >200     1485
# >300     1264
# Name: max_glu_serum, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'max_glu_serum has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# A1Cresult
# {'Top 5 value counts': None    84748
# >8       8216
# Norm     4990
# >7       3812
# Name: A1Cresult, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'A1Cresult has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# metformin
# {'Top 5 value counts': No        81778
# Steady    18346
# Up         1067
# Down        575
# Name: metformin, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'metformin has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# repaglinide
# {'Top 5 value counts': No        100227
# Steady      1384
# Up           110
# Down          45
# Name: repaglinide, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'repaglinide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# nateglinide
# {'Top 5 value counts': No        101063
# Steady       668
# Up            24
# Down          11
# Name: nateglinide, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'nateglinide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# chlorpropamide
# {'Top 5 value counts': No        101680
# Steady        79
# Up             6
# Down           1
# Name: chlorpropamide, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'chlorpropamide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# glimepiride
# {'Top 5 value counts': No        96575
# Steady     4670
# Up          327
# Down        194
# Name: glimepiride, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'glimepiride has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# acetohexamide
# {'Top 5 value counts': No        101765
# Steady         1
# Name: acetohexamide, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'acetohexamide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# glipizide
# {'Top 5 value counts': No        89080
# Steady    11356
# Up          770
# Down        560
# Name: glipizide, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'glipizide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# glyburide
# {'Top 5 value counts': No        91116
# Steady     9274
# Up          812
# Down        564
# Name: glyburide, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'glyburide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# tolbutamide
# {'Top 5 value counts': No        101743
# Steady        23
# Name: tolbutamide, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'tolbutamide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# pioglitazone
# {'Top 5 value counts': No        94438
# Steady     6976
# Up          234
# Down        118
# Name: pioglitazone, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'pioglitazone has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# rosiglitazone
# {'Top 5 value counts': No        95401
# Steady     6100
# Up          178
# Down         87
# Name: rosiglitazone, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'rosiglitazone has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# acarbose
# {'Top 5 value counts': No        101458
# Steady       295
# Up            10
# Down           3
# Name: acarbose, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'acarbose has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# miglitol
# {'Top 5 value counts': No        101728
# Steady        31
# Down           5
# Up             2
# Name: miglitol, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'miglitol has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# troglitazone
# {'Top 5 value counts': No        101763
# Steady         3
# Name: troglitazone, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'troglitazone has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# tolazamide
# {'Top 5 value counts': No        101727
# Steady        38
# Up             1
# Name: tolazamide, dtype: int64, 'Number of unique values': 3, 'data type': dtype('O'), 'Missing Values': 'tolazamide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# examide
# {'Top 5 value counts': No    101766
# Name: examide, dtype: int64, 'Number of unique values': 1, 'data type': dtype('O'), 'Missing Values': 'examide has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# citoglipton
# {'Top 5 value counts': No    101766
# Name: citoglipton, dtype: int64, 'Number of unique values': 1, 'data type': dtype('O'), 'Missing Values': 'citoglipton has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# insulin
# {'Top 5 value counts': No        47383
# Steady    30849
# Down      12218
# Up        11316
# Name: insulin, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'insulin has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# glyburide-metformin
# {'Top 5 value counts': No        101060
# Steady       692
# Up             8
# Down           6
# Name: glyburide-metformin, dtype: int64, 'Number of unique values': 4, 'data type': dtype('O'), 'Missing Values': 'glyburide-metformin has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# glipizide-metformin
# {'Top 5 value counts': No        101753
# Steady        13
# Name: glipizide-metformin, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'glipizide-metformin has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# glimepiride-pioglitazone
# {'Top 5 value counts': No        101765
# Steady         1
# Name: glimepiride-pioglitazone, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'glimepiride-pioglitazone has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# metformin-rosiglitazone
# {'Top 5 value counts': No        101764
# Steady         2
# Name: metformin-rosiglitazone, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'metformin-rosiglitazone has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# metformin-pioglitazone
# {'Top 5 value counts': No        101765
# Steady         1
# Name: metformin-pioglitazone, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'metformin-pioglitazone has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# change
# {'Top 5 value counts': No    54755
# Ch    47011
# Name: change, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'change has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# diabetesMed
# {'Top 5 value counts': Yes    78363
# No     23403
# Name: diabetesMed, dtype: int64, 'Number of unique values': 2, 'data type': dtype('O'), 'Missing Values': 'diabetesMed has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================
# readmitted
# {'Top 5 value counts': NO     54864
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64, 'Number of unique values': 3, 'data type': dtype('O'), 'Missing Values': 'readmitted has 0 missing values. This equates to 0.0 % missing'}
# ======================================================================

# %% [markdown]
# ### Observations:
# * There are 101,766 unique records with 71518 unique patients - This shows that it is possible that at least one or more patients has had at least 2 or more encounters that has forced them to be hospitalized.
# * Missing values form 3.79 % of this data and there are no duplicates in the data.
# * There are columns that have been given wrong types. For instance, columns like `encounter_id` and `patient_nbr` are taken as integers yet they are primary identifiers of the encounter and the patient in question respectively.
#
# * `gender` has a category known as 'Unknown/Invalid' which hints at missing values.
#
# * `weight` has over 96% of the column missing.
# * `admission_type_id`, `discharge_disposition_id` and `admission_source_id` are not really IDs in the conventional sense but are more like categorical variables which are nominal in nature- these features will be type casted to category.
#
# * `payer_code` has about 40% missing values and `medical_specialty` has about 50% missing values.
#
# * Other columns such as `race`, `diag_1`, `diag_2` and `diag_3` each have a small number of missing values with none of them having more than 3 % missing - these can be easily dropped. It is worth pointing out that these columns are supposed to be categorical columns because they provide information on the diagnoses given to the patient while taking on a limited number of categories without any inherent order. The study referred to these files for better understanding: 'https://github.com/WendyMwiti/Diabetes_Readmissions/blob/7a78a50202d6044b16bc601093845088f86266be/data/references'
#
# * Columns 24 to 46 are drug names. They are to be casted as category as they contain few categorical values that are repetitive.
#
# * Features of type object that are supposed to be object will be type casted to category.
#
# * The target column in this task is `readmitted` which tells us whether a patient was readmitted within 30 days, greater than 30 days or not readmitted at all.
#
# * The rows with consideration of the column `discharge_disposition_id` that hint towards the fact that the patient was taken to hospice or death will be removed as they do not help the model - they cannot be readmitted. They are denoted by values 11,13,14,19,20 and 21.
